# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.3.4'

# %%
d=pd.read_csv("C:\\Users\\Reesu Jagan\\Desktop\\test.csv")
df=pd.DataFrame(d)

# %%
df
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0       1           1043     1          1.8         1  14       0           5
# 1       2            841     1          0.5         1   4       1          61
# 2       3           1807     1          2.8         0   1       0          27
# 3       4           1546     0          0.5         1  18       1          25
# 4       5           1434     0          1.4         0  11       1          49
# ..    ...            ...   ...          ...       ...  ..     ...         ...
# 995   996           1700     1          1.9         0   0       1          54
# 996   997            609     0          1.8         1   0       0          13
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
# ...

# %%
df.head()
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# 1    0.8        191  ...  12        746       857  3895     6     0
# 2    0.9        186  ...   4       1270      1366  2396    17    10
# 3    0.5         96  ...  20        295      1752  3893    10     0
# 4    0.5        108  ...  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# ...

# %%
df.tail()
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 995   996           1700     1          1.9         0   0       1          54
# 996   997            609     0          1.8         1   0       0          13
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
#      m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 995    0.5        170  ...  17        644       913  2121    14     8
# 996    0.9        186  ...   2       1152      1632  1933     8     1
# 997    0.5         80  ...  12        477       825  1223     5     0
# 998    0.4        171  ...  12         38       832  2509    15    11
# 999    0.1        140  ...  19        457       608  2828     9     2
#
#      talk_time  three_g  touch_screen  wifi
# ...

# %%
df.describe()
# Out:
#                 id  battery_power         blue  clock_speed     dual_sim  \
# count  1000.000000    1000.000000  1000.000000  1000.000000  1000.000000
# mean    500.500000    1248.510000     0.516000     1.540900     0.517000
# std     288.819436     432.458227     0.499994     0.829268     0.499961
# min       1.000000     500.000000     0.000000     0.500000     0.000000
# 25%     250.750000     895.000000     0.000000     0.700000     0.000000
# 50%     500.500000    1246.500000     1.000000     1.500000     1.000000
# 75%     750.250000    1629.250000     1.000000     2.300000     1.000000
# max    1000.000000    1999.000000     1.000000     3.000000     1.000000
#
#                 fc       four_g   int_memory        m_dep   mobile_wt  ...  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000  ...
# mean      4.593000     0.487000    33.652000     0.517500   139.51100  ...
# std       4.463325     0.500081    18.128694     0.280861    34.85155  ...
# ...

# %%
df.shape
# Out:
# (1000, 21)

# %%
df[0:10:2]
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 2   3           1807     1          2.8         0   1       0          27
# 4   5           1434     0          1.4         0  11       1          49
# 6   7           1718     0          2.4         0   1       0          47
# 8   9           1111     1          2.9         1   9       1          25
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# 2    0.9        186  ...   4       1270      1366  2396    17    10
# 4    0.5        108  ...  18        749       810  1773    15     8
# 6    1.0        156  ...   3       1283      1374  3873    14     2
# 8    0.6        101  ...  19        556       876  3485    11     9
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# ...

# %%
df[['dual_sim','fc']][0:10]
# Out:
#    dual_sim  fc
# 0         1  14
# 1         1   4
# 2         0   1
# 3         1  18
# 4         0  11
# 5         1   5
# 6         0   1
# 7         1   0
# 8         1   9
# 9         0   1

# %%
for rec in df.iterrows():
    print(rec)
# Out:
# (0, id                  1.0
# battery_power    1043.0
# blue                1.0
# clock_speed         1.8
# dual_sim            1.0
# fc                 14.0
# four_g              0.0
# int_memory          5.0
# m_dep               0.1
# mobile_wt         193.0
# n_cores             3.0
# pc                 16.0
# px_height         226.0
# px_width         1412.0
# ram              3476.0
# sc_h               12.0
# sc_w                7.0
# talk_time           2.0
# three_g             0.0
# touch_screen        1.0
# wifi                0.0
# Name: 0, dtype: float64)
# (1, id                  2.0
# battery_power     841.0
# blue                1.0
# clock_speed         0.5
# dual_sim            1.0
# fc                  4.0
# four_g              1.0
# int_memory         61.0
# m_dep               0.8
# mobile_wt         191.0
# n_cores             5.0
# pc                 12.0
# px_height         746.0
# px_width          857.0
# ram              3895.0
# sc_h                6.0
# ...

# %%
df.loc[1]
# Out:
# id                  2.0
# battery_power     841.0
# blue                1.0
# clock_speed         0.5
# dual_sim            1.0
# fc                  4.0
# four_g              1.0
# int_memory         61.0
# m_dep               0.8
# mobile_wt         191.0
# n_cores             5.0
# pc                 12.0
# px_height         746.0
# px_width          857.0
# ram              3895.0
# sc_h                6.0
# sc_w                0.0
# talk_time           7.0
# three_g             1.0
# touch_screen        0.0
# wifi                0.0
# Name: 1, dtype: float64

# %%
df.loc[19,['blue']]
# Out:
# blue    0.0
# Name: 19, dtype: float64

# %%
df.iloc[0:5]
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# 1    0.8        191  ...  12        746       857  3895     6     0
# 2    0.9        186  ...   4       1270      1366  2396    17    10
# 3    0.5         96  ...  20        295      1752  3893    10     0
# 4    0.5        108  ...  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# ...

# %%
df.loc[0:4,'blue':'fc']
# Out:
#    blue  clock_speed  dual_sim  fc
# 0     1          1.8         1  14
# 1     1          0.5         1   4
# 2     1          2.8         0   1
# 3     0          0.5         1  18
# 4     0          1.4         0  11

# %%
df.iloc[2,1]
# Out:
# 1807

# %%
 df.sort_values('blue',ascending=False)
# Out:
#       id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0      1           1043     1          1.8         1  14       0           5
# 568  569           1189     1          2.5         0   4       1          20
# 555  556           1074     1          1.5         1   5       0           9
# 556  557           1411     1          2.6         0   0       0          61
# 557  558           1502     1          2.2         1   0       1          16
# ..   ...            ...   ...          ...       ...  ..     ...         ...
# 212  213           1001     0          0.8         0   0       0          48
# 587  588            763     0          1.2         1   4       1          59
# 586  587            941     0          1.3         1   3       0          26
# 585  586            583     0          0.5         1   1       1          62
# 166  167           1547     0          2.5         0  12       1          50
#
# ...

# %%
df.sort_values(['blue','fc'])
# Out:
#       id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 7      8            833     0          2.4         1   0       0          62
# 26    27           1858     0          3.0         1   0       0          17
# 39    40            567     0          2.6         0   0       0           2
# 94    95            679     0          0.9         1   0       0          41
# 104  105            697     0          0.6         1   0       1          34
# ..   ...            ...   ...          ...       ...  ..     ...         ...
# 284  285            669     1          2.6         1  18       1          10
# 749  750           1348     1          0.5         1  18       0          40
# 784  785           1055     1          1.2         1  18       1          29
# 520  521            769     1          0.6         1  19       1          52
# 580  581           1506     1          2.9         1  19       1          47
#
# ...

# %%
df['total']=0

# %%
df
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0       1           1043     1          1.8         1  14       0           5
# 1       2            841     1          0.5         1   4       1          61
# 2       3           1807     1          2.8         0   1       0          27
# 3       4           1546     0          0.5         1  18       1          25
# 4       5           1434     0          1.4         0  11       1          49
# ..    ...            ...   ...          ...       ...  ..     ...         ...
# 995   996           1700     1          1.9         0   0       1          54
# 996   997            609     0          1.8         1   0       0          13
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
# ...

# %%
df['total']=df['blue']+df['fc']

# %%
df
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0       1           1043     1          1.8         1  14       0           5
# 1       2            841     1          0.5         1   4       1          61
# 2       3           1807     1          2.8         0   1       0          27
# 3       4           1546     0          0.5         1  18       1          25
# 4       5           1434     0          1.4         0  11       1          49
# ..    ...            ...   ...          ...       ...  ..     ...         ...
# 995   996           1700     1          1.9         0   0       1          54
# 996   997            609     0          1.8         1   0       0          13
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
# ...

# %%
df['perc']='pass/fail'

# %%
df
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0       1           1043     1          1.8         1  14       0           5
# 1       2            841     1          0.5         1   4       1          61
# 2       3           1807     1          2.8         0   1       0          27
# 3       4           1546     0          0.5         1  18       1          25
# 4       5           1434     0          1.4         0  11       1          49
# ..    ...            ...   ...          ...       ...  ..     ...         ...
# 995   996           1700     1          1.9         0   0       1          54
# 996   997            609     0          1.8         1   0       0          13
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
# ...

# %%
df.drop(columns='perc')
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0       1           1043     1          1.8         1  14       0           5
# 1       2            841     1          0.5         1   4       1          61
# 2       3           1807     1          2.8         0   1       0          27
# 3       4           1546     0          0.5         1  18       1          25
# 4       5           1434     0          1.4         0  11       1          49
# ..    ...            ...   ...          ...       ...  ..     ...         ...
# 995   996           1700     1          1.9         0   0       1          54
# 996   997            609     0          1.8         1   0       0          13
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
# ...

# %%
df.drop(columns='perc',inplace=)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\REESUJ~1\AppData\Local\Temp/ipykernel_7960/2284646624.py in <module>
# ----> 1 df.drop(columns='perc',inplace=False)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
df
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0       1           1043     1          1.8         1  14       0           5
# 1       2            841     1          0.5         1   4       1          61
# 2       3           1807     1          2.8         0   1       0          27
# 3       4           1546     0          0.5         1  18       1          25
# 4       5           1434     0          1.4         0  11       1          49
# ..    ...            ...   ...          ...       ...  ..     ...         ...
# 995   996           1700     1          1.9         0   0       1          54
# 996   997            609     0          1.8         1   0       0          13
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
#missing data
df.dropna(4)
# Out:
# C:\Users\REESUJ~1\AppData\Local\Temp/ipykernel_7960/669077780.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only
#   df.dropna(4)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     545         try:
# --> 546             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     547         except KeyError:
#
# KeyError: 4
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# C:\Users\REESUJ~1\AppData\Local\Temp/ipykernel_7960/669077780.py in <module>
#       1 #missing data
# ----> 2 df.dropna(4)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
# ...

# %%
df.fillna(8)
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0       1           1043     1          1.8         1  14       0           5
# 1       2            841     1          0.5         1   4       1          61
# 2       3           1807     1          2.8         0   1       0          27
# 3       4           1546     0          0.5         1  18       1          25
# 4       5           1434     0          1.4         0  11       1          49
# ..    ...            ...   ...          ...       ...  ..     ...         ...
# 995   996           1700     1          1.9         0   0       1          54
# 996   997            609     0          1.8         1   0       0          13
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
# ...

# %%
df
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0       1           1043     1          1.8         1  14       0           5
# 1       2            841     1          0.5         1   4       1          61
# 2       3           1807     1          2.8         0   1       0          27
# 3       4           1546     0          0.5         1  18       1          25
# 4       5           1434     0          1.4         0  11       1          49
# ..    ...            ...   ...          ...       ...  ..     ...         ...
# 995   996           1700     1          1.9         0   0       1          54
# 996   997            609     0          1.8         1   0       0          13
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
# ...

# %%
df.loc[df['clock_speed']>2]
# Out:
#       id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 2      3           1807     1          2.8         0   1       0          27
# 5      6           1464     1          2.9         1   5       1          50
# 6      7           1718     0          2.4         0   1       0          47
# 7      8            833     0          2.4         1   0       0          62
# 8      9           1111     1          2.9         1   9       1          25
# ..   ...            ...   ...          ...       ...  ..     ...         ...
# 981  982            829     0          2.6         1  11       1          10
# 985  986            971     1          2.1         0   9       0           7
# 986  987            991     0          2.6         0   0       0          19
# 991  992           1797     1          2.6         0   4       0          42
# 993  994            567     1          2.7         1  14       1          56
#
# ...

# %%
 df.loc[df["battery_power"].str.contains(8)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\REESUJ~1\AppData\Local\Temp/ipykernel_7960/916423008.py in <module>
# ----> 1 df.loc[df["battery_power"].str.contains(8)]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     179             # we're accessing the attribute of the class, i.e., Dataset.geo
#     180             return self._accessor
# --> 181         accessor_obj = self._accessor(obj)
#     182         # Replace the property with the accessor object. Inspired by:
# ...

# %%
df
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0       1           1043     1          1.8         1  14       0           5
# 1       2            841     1          0.5         1   4       1          61
# 2       3           1807     1          2.8         0   1       0          27
# 3       4           1546     0          0.5         1  18       1          25
# 4       5           1434     0          1.4         0  11       1          49
# ..    ...            ...   ...          ...       ...  ..     ...         ...
# 995   996           1700     1          1.9         0   0       1          54
# 996   997            609     0          1.8         1   0       0          13
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
# ...

# %%
df.loc[df['total']>1,['total']]=10

# %%
df
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0       1           1043     1          1.8         1  14       0           5
# 1       2            841     1          0.5         1   4       1          61
# 2       3           1807     1          2.8         0   1       0          27
# 3       4           1546     0          0.5         1  18       1          25
# 4       5           1434     0          1.4         0  11       1          49
# ..    ...            ...   ...          ...       ...  ..     ...         ...
# 995   996           1700     1          1.9         0   0       1          54
# 996   997            609     0          1.8         1   0       0          13
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
# ...

# %%
df.to_csv("C:\\Users\\Reesu Jagan\\Desktop\\modified.csv",index=False)

# %%
df
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0       1           1043     1          1.8         1  14       0           5
# 1       2            841     1          0.5         1   4       1          61
# 2       3           1807     1          2.8         0   1       0          27
# 3       4           1546     0          0.5         1  18       1          25
# 4       5           1434     0          1.4         0  11       1          49
# ..    ...            ...   ...          ...       ...  ..     ...         ...
# 995   996           1700     1          1.9         0   0       1          54
# 996   997            609     0          1.8         1   0       0          13
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
# ...
